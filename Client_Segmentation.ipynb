# %%
# import required libraries for dataframe and visualization

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# import required libraries for clustering
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
csv_file_path = r"E:\AIML Project\RetailDataset.csv"

if pd.io.common.file_exists(csv_file_path):
    retail = pd.read_csv(csv_file_path, sep=",", encoding="ISO-8859-1", header=0)
    print("First few rows:")
    print(retail.head())
    print("\nLast few rows:")
    print(retail.tail())
else:
    print(f"The file '{csv_file_path}' does not exist.")
# Out:
# First few rows:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom
#
# Last few rows:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# ...

# %%
data_shape = retail.shape

print("Shape of the DataFrame:", data_shape)
# Out:
# Shape of the DataFrame: (541909, 8)

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
retail.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# <a id="2"></a> <br>
# ## Data Cleansing

# %%
df_null = round(100*(retail.isnull().sum())/len(retail), 2)
df_null
# Out:
# InvoiceNo       0.00
# StockCode       0.00
# Description     0.27
# Quantity        0.00
# InvoiceDate     0.00
# UnitPrice       0.00
# CustomerID     24.93
# Country         0.00
# dtype: float64

# %%
retail = retail.dropna()
retail.shape
# Out:
# (406829, 8)

# %%
retail['CustomerID'] = retail['CustomerID'].astype(str)

# %% [markdown]
# <a id="3"></a> <br>
# ##  Data Preparation

# %% [markdown]
# ####  Analysis of  the Customers is based on below 3 factors:
# - Recency(R): Number of days since last purchase
# - Frequency(F): Number of transactions
# - Monetary(M): Total amount of transactions

# %%
retail['Amount'] = retail['Quantity']*retail['UnitPrice']
rfm_m = retail.groupby('CustomerID')['Amount'].sum()
rfm_m = rfm_m.reset_index()
rfm_m.head()
# Out:
#   CustomerID   Amount
# 0    12346.0     0.00
# 1    12347.0  4310.00
# 2    12348.0  1797.24
# 3    12349.0  1757.55
# 4    12350.0   334.40

# %%
rfm_f = retail.groupby('CustomerID')['InvoiceNo'].count()
rfm_f = rfm_f.reset_index()
rfm_f.columns = ['CustomerID', 'Frequency']
rfm_f.head()
# Out:
#   CustomerID  Frequency
# 0    12346.0          2
# 1    12347.0        182
# 2    12348.0         31
# 3    12349.0         73
# 4    12350.0         17

# %%
rfm = pd.merge(rfm_m, rfm_f, on='CustomerID', how='inner')
rfm.head()
# Out:
#   CustomerID   Amount  Frequency
# 0    12346.0     0.00          2
# 1    12347.0  4310.00        182
# 2    12348.0  1797.24         31
# 3    12349.0  1757.55         73
# 4    12350.0   334.40         17

# %%
retail['InvoiceDate'] = pd.to_datetime(retail['InvoiceDate'],format='%d-%m-%Y %H:%M')

# %%
max_date = max(retail['InvoiceDate'])
max_date
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
retail['Diff'] = max_date - retail['InvoiceDate']
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom   20.34
#
#                Diff
# 0 373 days 04:24:00
# 1 373 days 04:24:00
# 2 373 days 04:24:00
# 3 373 days 04:24:00
# 4 373 days 04:24:00

# %%
rfm_p = retail.groupby('CustomerID')['Diff'].min()
rfm_p = rfm_p.reset_index()
rfm_p.head()
# Out:
#   CustomerID              Diff
# 0    12346.0 325 days 02:33:00
# 1    12347.0   1 days 20:58:00
# 2    12348.0  74 days 23:37:00
# 3    12349.0  18 days 02:59:00
# 4    12350.0 309 days 20:49:00

# %%
rfm_p['Diff'] = rfm_p['Diff'].dt.days
rfm_p.head()
# Out:
#   CustomerID  Diff
# 0    12346.0   325
# 1    12347.0     1
# 2    12348.0    74
# 3    12349.0    18
# 4    12350.0   309

# %%
rfm = pd.merge(rfm, rfm_p, on='CustomerID', how='inner')
rfm.columns = ['CustomerID', 'Amount', 'Frequency', 'Recency']
rfm.head()
# Out:
#   CustomerID   Amount  Frequency  Recency
# 0    12346.0     0.00          2      325
# 1    12347.0  4310.00        182        1
# 2    12348.0  1797.24         31       74
# 3    12349.0  1757.55         73       18
# 4    12350.0   334.40         17      309

# %% [markdown]
# #### There are 2 types of outliers and we will treat outliers as it can skew our dataset
# - Statistical
# - Domain specific

# %%
selected_attributes = ['Amount', 'Frequency', 'Recency']
plt.rcParams['figure.figsize'] = [9, 9]
sns.boxplot(data=rfm[selected_attributes], orient="v", palette="Pastel2", whis=1.5, saturation=1, width=0.8)
plt.title("Distribution of Outlier Variables", fontsize=16, fontweight='bold')
plt.ylabel("Value Range", fontweight='bold')
plt.xlabel("Selected Attributes", fontweight='bold')
# Out:
# Text(0.5, 0, 'Selected Attributes')

# %%
Q1 = rfm.Amount.quantile(0.05)
Q3 = rfm.Amount.quantile(0.95)
IQR = Q3 - Q1
rfm = rfm[(rfm.Amount >= Q1 - 1.5*IQR) & (rfm.Amount <= Q3 + 1.5*IQR)]

Q1 = rfm.Recency.quantile(0.05)
Q3 = rfm.Recency.quantile(0.95)
IQR = Q3 - Q1
rfm = rfm[(rfm.Recency >= Q1 - 1.5*IQR) & (rfm.Recency <= Q3 + 1.5*IQR)]

Q1 = rfm.Frequency.quantile(0.05)
Q3 = rfm.Frequency.quantile(0.95)
IQR = Q3 - Q1
rfm = rfm[(rfm.Frequency >= Q1 - 1.5*IQR) & (rfm.Frequency <= Q3 + 1.5*IQR)]

# %% [markdown]
# ### Scaling the Attributes
#
# Ensuring variables share a comparable scale is crucial for analysis. Two common rescaling methods include:
#
# 1. Min-Max scaling
# 2. Standardisation (mean-0, sigma-1)
#
# Here, we will use Standardisation Scaling.

# %%
rfm_df = rfm[['Amount', 'Frequency', 'Recency']]

scaler = StandardScaler()

rfm_df_scaled = scaler.fit_transform(rfm_df)
rfm_df_scaled.shape
# Out:
# (4293, 3)

# %%
rfm_df_scaled = pd.DataFrame(rfm_df_scaled)
rfm_df_scaled.columns = ['Amount', 'Frequency', 'Recency']
rfm_df_scaled.head()
# Out:
#      Amount  Frequency   Recency
# 0 -0.723738  -0.752888  2.301611
# 1  1.731617   1.042467 -0.906466
# 2  0.300128  -0.463636 -0.183658
# 3  0.277517  -0.044720 -0.738141
# 4 -0.533235  -0.603275  2.143188

# %% [markdown]
# <a id="4"></a> <br>
# ## Building the Model

# %% [markdown]
# ### K-Means Clustering

# %% [markdown]
# K-means clustering is one of the simplest and popular unsupervised machine learning algorithms.<br>
#
# The algorithm works as follows:
#
# - First we initialize k points, called means, randomly.
# - We categorize each item to its closest mean and we update the mean’s coordinates, which are the averages of the items categorized in that mean so far.
# - We repeat the process for a given number of iterations and at the end, we have our clusters.

# %%
kmeans = KMeans(max_iter=50, n_clusters=4, n_init=10)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=4, n_init=10)

# %%
kmeans.labels_
# Out:
# array([3, 2, 0, ..., 3, 0, 0])

# %% [markdown]
# ### Finding the Optimal Number of Clusters

# %% [markdown]
# #### Elbow Curve to get the right number of Clusters
# A fundamental step for any unsupervised algorithm is to determine the optimal number of clusters into which the data may be clustered. The Elbow Method is one of the most popular methods to determine this optimal value of k.

# %%
ssd = []
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50, n_init=10)  
    kmeans.fit(rfm_df_scaled)
    
    ssd.append(kmeans.inertia_)

plt.plot(range_n_clusters, ssd, marker='o')
plt.title('Elbow Curve')
plt.xlabel('Number of Clusters')
plt.ylabel('Sum of Squared Distances (SSD)')
plt.show()

# %% [markdown]
# ### Silhouette Analysis
#
# $$\text{silhouette score}=\frac{p-q}{max(p,q)}$$
#
# $p$ is the mean distance to the points in the nearest cluster that the data point is not a part of
#
# $q$ is the mean intra-cluster distance to all the points in its own cluster.
#
# * The value of the silhouette score range lies between -1 to 1.
#
# * A score closer to 1 indicates that the data point is very similar to other data points in the cluster,
#
# * A score closer to -1 indicates that the data point is not similar to the data points in its cluster.

# %%
from sklearn.metrics import silhouette_score

range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    
    
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50, n_init=10)
    kmeans.fit(rfm_df_scaled)
    
    cluster_labels = kmeans.labels_
    
    
    silhouette_avg = silhouette_score(rfm_df_scaled, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.5415858652525395
# For n_clusters=3, the silhouette score is 0.5084896296141937
# For n_clusters=4, the silhouette score is 0.4777820100216849
# For n_clusters=5, the silhouette score is 0.46627005641897035
# For n_clusters=6, the silhouette score is 0.41698971636412085
# For n_clusters=7, the silhouette score is 0.4173415738634804
# For n_clusters=8, the silhouette score is 0.4029005216190826

# %%
# Final model with k=3
kmeans = KMeans(n_clusters=3, max_iter=50, n_init=10)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=3, n_init=10)

# %%
 kmeans.labels_
# Out:
# array([2, 1, 0, ..., 2, 0, 0])

# %%
rfm['Cluster_Id'] = kmeans.labels_
rfm.head()
# Out:
#   CustomerID   Amount  Frequency  Recency  Cluster_Id
# 0    12346.0     0.00          2      325           2
# 1    12347.0  4310.00        182        1           1
# 2    12348.0  1797.24         31       74           0
# 3    12349.0  1757.55         73       18           0
# 4    12350.0   334.40         17      309           2

# %%
sns.boxplot(x='Cluster_Id', y='Amount', data=rfm)
# Out:
# <Axes: xlabel='Cluster_Id', ylabel='Amount'>

# %%
sns.boxplot(x='Cluster_Id', y='Frequency', data=rfm)
# Out:
# <Axes: xlabel='Cluster_Id', ylabel='Frequency'>

# %%
sns.boxplot(x='Cluster_Id', y='Recency', data=rfm)
# Out:
# <Axes: xlabel='Cluster_Id', ylabel='Recency'>

# %% [markdown]
# ### Hierarchical Clustering
#
# Hierarchical clustering involves creating clusters that have a predetermined ordering from top to bottom. For example, all files and folders on the hard disk are organized in a hierarchy. There are two types of hierarchical clustering,
# - Divisive
# - Agglomerative.

# %% [markdown]
# **Single Linkage:<br>**
#
# In single linkage hierarchical clustering, the distance between two clusters is defined as the shortest distance between two points in each cluster. For example, the distance between clusters “r” and “s” to the left is equal to the length of the arrow between their two closest points.
# ![](https://www.saedsayad.com/images/Clustering_single.png)

# %%
mergings = linkage(rfm_df_scaled, method="single", metric='euclidean')
dendrogram(mergings)
plt.show()

# %% [markdown]
# **Complete Linkage<br>**
#
# In complete linkage hierarchical clustering, the distance between two clusters is defined as the longest distance between two points in each cluster. For example, the distance between clusters “r” and “s” to the left is equal to the length of the arrow between their two furthest points.
# ![](https://www.saedsayad.com/images/Clustering_complete.png)

# %%
mergings = linkage(rfm_df_scaled, method="complete", metric='euclidean')
dendrogram(mergings)
plt.show()

# %% [markdown]
# **Average Linkage:<br>**
#
# In average linkage hierarchical clustering, the distance between two clusters is defined as the average distance between each point in one cluster to every point in the other cluster. For example, the distance between clusters “r” and “s” to the left is equal to the average length each arrow between connecting the points of one cluster to the other.
# ![](https://www.saedsayad.com/images/Clustering_average.png)

# %%
mergings = linkage(rfm_df_scaled, method="average", metric='euclidean')
dendrogram(mergings)
plt.show()

# %% [markdown]
# #### Cutting the Dendrogram based on K

# %%
cluster_labels = cut_tree(mergings, n_clusters=3).reshape(-1, )
cluster_labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
rfm['Cluster_Labels'] = cluster_labels
rfm.head()
# Out:
#   CustomerID   Amount  Frequency  Recency  Cluster_Id  Cluster_Labels
# 0    12346.0     0.00          2      325           2               0
# 1    12347.0  4310.00        182        1           1               0
# 2    12348.0  1797.24         31       74           0               0
# 3    12349.0  1757.55         73       18           0               0
# 4    12350.0   334.40         17      309           2               0

# %%
sns.boxplot(x='Cluster_Labels', y='Amount', data=rfm)
# Out:
# <Axes: xlabel='Cluster_Labels', ylabel='Amount'>

# %%
sns.boxplot(x='Cluster_Labels', y='Frequency', data=rfm)
# Out:
# <Axes: xlabel='Cluster_Labels', ylabel='Frequency'>

# %%
sns.boxplot(x='Cluster_Labels', y='Recency', data=rfm)
# Out:
# <Axes: xlabel='Cluster_Labels', ylabel='Recency'>

# %%
from sklearn.metrics import calinski_harabasz_score

kmeans = KMeans(n_clusters=3, max_iter=50, n_init=10)
kmeans.fit(rfm_df_scaled)

kmeans_labels = kmeans.labels_

calinski_score_kmeans = calinski_harabasz_score(rfm_df_scaled, kmeans_labels)
print(f"Calinski-Harabasz Score for K-Means: {calinski_score_kmeans}")

mergings = linkage(rfm_df_scaled, method="average", metric='euclidean')
cluster_labels = cut_tree(mergings, n_clusters=3).reshape(-1, )

calinski_score_hierarchical = calinski_harabasz_score(rfm_df_scaled, cluster_labels)
print(f"Calinski-Harabasz Score for Hierarchical Clustering: {calinski_score_hierarchical}")
# Out:
# Calinski-Harabasz Score for K-Means: 4085.9580837955855
# Calinski-Harabasz Score for Hierarchical Clustering: 1362.190634643421

# %% [markdown]
# ### Inference:
# K-Means Clustering with 3 Cluster Ids
# - Customers with Cluster Id 1 are the customers with high amount of transactions as compared to other customers.
# - Customers with Cluster Id 1 are frequent buyers.
# - Customers with Cluster Id 2 are not recent buyers and hence least of importance from business point of view.

# %% [markdown]
# Hierarchical Clustering with 3 Cluster Labels
# - Customers with Cluster_Labels 2 are the customers with high amount of transactions as compared to other customers.
# - Customers with Cluster_Labels 2 are frequent buyers.
# - Customers with Cluster_Labels 0 are not recent buyers and hence least of importance from business point of view.
